# %% [markdown]
# # Fluvial Sedimentary Response to Large Deep-Seated Landslide Event(s)
# ## CSDMS ESPIn 2024 Lab: Event-Sediment-Pulse Team
# Contributors (listed in the alphabetic order of last name):
# - **Nilay Iscen**          *(University of Minnesota, St. Anthony Falls Laboratory)*
# - **John Kemper**          *(Utah State University, Department of Watershed Sciences)*
# - **Larry Syu-Heng Lai**   *(University of Washington, Department of Earth and Space Sciences)*
# - **Yuan Li**              *(University of Virginia, Department of Environmental Sciences)*
#
# ---

# %% [markdown]
# ## Introduction
#
# Watersheds are increasingly understood to function as connected networks, with the strength of connections between landscape compartments – for example, hillslopes and river channels – controlling various system dynamics (Figure 1) (Fryirs, 2013). In mountain landscapes, where catastrophic hillslope processes like landslides are important and potentially fairly frequent events, the response of a particular watershed to a spate of landslide activity is likely strongly influenced by this coupling. The strength of this coupling is controlled, at least in part, by the hydrology of the watershed in question. In relatively dry landscapes (like, for example, the semi-arid Colorado Front Range or the mesas of the Colorado Western Slope (Figure 2, right-hand side)), landslides that occur may be largely disconnected from valley bottom rivers, with sediment deposits that remain stored on hillslopes for many years, safe from the hydrologic highway offered by steep mountain rivers. Conversely, in relatively wet landscapes (like, for example, Taiwan or Pacific Northwest (Figure 2, left-hand side)), landslides may be fairly well-connected to valley bottom rivers, with landslide-generated sediment transported relatively quickly downslope by subsequent rainfall events. The time it takes for these two landscapes to transport sediment produced by landslides is thus likely very different: in the former, it may take centuries to evacuate, whereas in the latter, a pronounced sediment response may occur in the years immediately following hillslope failure. The time scale of response is important for many reasons, including short-term management concerns – like anticipating how long river flooding may occur following large mass movement events – to long-term landscape development questions – like how landslides influence downstream river erosion and the form and shape of mountain landscapes.
#
# <img src="connectivity_img.jpg" alt="drawing" width="400"/>
#
# *Figure 1. A graphical depiction of connectivity, with barriers to connectivity (i.e., low connectivity) represent by red symbols*
#
# <img src="MotivationImg.jpg" alt="drawing" width="800"/>
#
# *Figure 2. Left: 2014 Oso Landlside, WA (Source: The Seattle Times) Right: 2014 West Salt Creek Landslide, CO (Source: USGS)*
#
# ---

# %% [markdown]
# In this notebook, we will simulate these sorts of different landscapes using `Landlab` v2.7 and various components. We will do this by running the following two hillslope-river connectivity scenarios to investigate how the river network may respond to an catastrophic landslide period:
#
# 1.	High-connectivity scenario: Here, we simulate landslide occurrence over a 20-year period that occurs simultaneously with fluvial processes (flow routing, erosion, etc.). This represents our wet landscape, where landslide sediment is frequently transported downslope to river channels by rainfall events. We then run this same model forward 20 more years to see how the river network evacuates sediment in these sorts of well-connected landscapes.
#
# 2.	Low-connectivity scenario: Here, we simulate landslide occurrence over the same 20-year period, but we turn off fluvial and hydrological processes, essentially "stranding" the landslide sediment on the hillslopes. This represents our dry landscape, where landslide-derived sediment may remain perched high above river channels. We then "turn on" hydrological and fluvial processes and run the model forward several years, to see how the river network evacuates sediment in these more poorly connected landscapes.
#
# We will utilize the **`SPACE`**, **`GravelBedrockEroder`**, **`BedrockLandslider`**, **`FlowAccumulator`**, and **`MassWastingRunout`** components to perform the analysis through following steps:
#
# * Step 1: Setup an steady-state initial landscape before catastropic landslide event
#     * Run simulation using `SPACE` model
#     * Show the landform, sediment thickness, and river long-profile for the main trunk
#
# * Step 2: Testing a scenario with **GOOD** hillslope-channel connectivity:
#     * 2.1: Run simulation using Hyland (`BedrockLandslider`) **and** `GravelBedrockEroder` in every iteration for 20 years,
#     * 2.2: Run `GravelBedrockEroder` only over 20000 years **after** the landslide event, and animate the results.
#
# * Step 3: Testing a scenario with **BAD** hillslope-channel connectivity:
#     * 3.1: Run simulation using Hyland (`BedrockLandslider`) only for 20 years - no river transport and incision.
#     * 3.2: Run `GravelBedrockEroder` only over 20000 years **after** the landslide event, and animate the results.
#
# * Step EXTRA: Testing a scenario **BAD** connectivity scenario with real landscape DEM:
#     * Extra.1: Load and plot the real landscape DEM
#     * Extra.2: Load and plot the DEM with imposed landslide event using Hyland (`BedrockLandslider`) generated from other teams.
#     * Extra.3: Run `GravelBedrockEroder` only over 10000 years **after** the landslide event, and animate the results.
#
# References:
# * Shobe, C. M., Tucker, G. E., and Barnhart, K. R.: The SPACE 1.0 model: a Landlab component for 2-D calculation of sediment transport, bedrock erosion, and landscape evolution, Geosci. Model Dev., 10, 4577-4604, https://doi.org/10.5194/gmd-10-4577-2017, 2017.
# * Campforts, B., Shobe, C. M., Steer, P., Vanmaercke, M., Lague, D., and Braun, J.: HyLands 1.0: a hybrid landscape evolution model to simulate the impact of landslides and landslide-derived sediment on landscape evolution, Geosci. Model Dev., 13, 3863–3886, https://doi.org/10.5194/gmd-13-3863-2020, 2020.
# * GravelBedrockEroder: rock incision, bed-load transport, and downstream abrasion in a river network. https://landlab.readthedocs.io/en/latest/reference/components/gravel_bedrock_eroder.html
#
# ---

# %% [markdown]
# ### Importing necessary libraries and components:

# %%
# Import necessary libraries and components
import copy
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import imageio  # For creating GIT animation
import os       # For loading and saving figures
import pickle   # For saving and loading landlab grid objects
from IPython.display import Image, display # For showing images and animations

# Import Landlab components
from landlab import RasterModelGrid
from landlab import imshow_grid
from landlab.components import BedrockLandslider        # For simulating landslides
from landlab.components import SpaceLargeScaleEroder    # For simulating fluvial erosion
from landlab.components import PriorityFloodFlowRouter  # For routing flow
from landlab.components import GravelBedrockEroder      # For simulating bedrock erosion
from landlab.components import ChannelProfiler          # For extracting channel profiles

# %% [markdown]
# ### Define plotting functions for long-profile of the trunk channel and landscape evolution:

# %%
def plot_landscape_and_profile(mg, title="Landscape and Profile", showfig=True, savefig=False, savefigname=None, max_sed_depth=None):
    """
    Plot landscape evolution and long profile in a single figure.
    Upper panel: Terrain & Channels (left) and Soil depth (right)
    Lower panel: Long profile of the trunk channel
    
    Parameters:
    - mg: Landlab model grid
    - title: Title for the entire figure
    - showfig: Boolean, whether to show the figure
    - savefig: Boolean, whether to save the figure
    - savefigname: String, filename to save the figure (if savefig is True)
    - max_sed_depth: Float, maximum sediment depth for consistent y-axis limit
    """
    # Create figure and gridspec for layout
    fig = plt.figure(figsize=(12, 10))
    gs = fig.add_gridspec(2, 2, height_ratios=[1, 1])

    # Upper left: Terrain & Channels
    ax1 = fig.add_subplot(gs[0, 0])
    # Initialize ChannelProfiler to extract channel network
    profiler = ChannelProfiler(mg, number_of_watersheds=1, minimum_channel_threshold=625, main_channel_only=True)
    profiler.run_one_step()
    cmap_terrain = copy.copy(mpl.colormaps["terrain"])
    plt.sca(ax1)
    profiler.plot_profiles_in_map_view(cmap=cmap_terrain)
    ax1.set_title("Terrain & Channels")

    # Upper right: Soil depth
    ax2 = fig.add_subplot(gs[0, 1])
    cmap_pink = copy.copy(mpl.colormaps["pink"])
    plt.sca(ax2)
    im = imshow_grid(
        mg,
        mg.at_node["soil__depth"],
        colorbar_label="Soil depth (m)",
        cmap=cmap_pink
    )
    ax2.set_title("Soil depth")

    # Lower: Long profile
    ax3 = fig.add_subplot(gs[1, :])
    ax4 = ax3.twinx()  # Create a twin axis for sediment thickness

    # Extract data for the main channel
    riv_nodes = profiler.nodes[0]  # Main channel nodes
    mg.at_node["bedrock_elevation"] = mg.at_node["topographic__elevation"] - mg.at_node["soil__depth"]
    dist_atNodes = profiler.distance_along_profile[0]

    el = mg.at_node["topographic__elevation"][riv_nodes]
    sd = mg.at_node["soil__depth"][riv_nodes]
    br = el - sd

    # Calculate relief
    min_elevation = min(np.min(el), np.min(br))
    el_relief = el - min_elevation
    br_relief = br - min_elevation

    # Convert distance to km
    dist = (max(dist_atNodes) - dist_atNodes) * 1e-3
    brown_c = [205/255, 133/255, 63/255]  # Color for colluvial material

    # Plot relief and soil depth
    ax3.fill_between(dist, np.max(el_relief), 0, color='lightgrey', label='total area')
    ax3.fill_between(dist, br_relief, 0, color='grey', label='bedrock')
    ax3.fill_between(dist, el_relief, br_relief, color=brown_c, label='colluvial material')

    lns2 = ax3.plot(dist, br_relief, color='k', label='bedrock', linewidth=0.8, zorder=3)
    lns1 = ax3.plot(dist, el_relief, color='brown', label='topo', linewidth=1, zorder=4)

    ax3.set_xlabel('Distance Along Profile (km)', fontweight='normal', fontsize=10.0)
    ax3.set_ylabel('Relief (m)', fontweight='normal', fontsize=10.0)
    ax3.set_ylim((np.min(el_relief), np.max(el_relief) * 1.1))
    ax3.tick_params(labelsize=10.0)

    # Plot sediment thickness on the twin axis
    lns3 = ax4.plot(dist, sd, color='orange', label='sediment', linewidth=0.8)
    ax4.set_ylabel('Sediment thickness (m)', fontweight='normal', fontsize=10.0)
    if max_sed_depth is not None:
        ax4.set_ylim((0, max_sed_depth * 1.3))
    else:
        ax4.set_ylim((0, np.nanmax(sd) * 1.3))
    ax4.tick_params(labelsize=10.0)

    # Combine legends
    lns = lns1 + lns2 + lns3
    labs = [l.get_label() for l in lns]
    ax3.legend(lns, labs, fontsize=10.0)
    ax3.set_ylim(bottom=0)

    ax3.set_title("Long Profile of Main Trunk")

    plt.tight_layout()
    fig.suptitle(title, fontsize=14, y=1.02)
    
    if savefig and savefigname:
        plt.savefig(savefigname, dpi=100, bbox_inches='tight')
    
    if showfig:
        plt.show()
    else:
        plt.close(fig)

# %% [markdown]
# ##### Functions for GIF animation

# %%
# For creating the GIF animation
def create_gif(image_folder, gif_name, duration=0.5, loop=0):
    """
    Create a looping GIF from a series of PNG images.
    
    Parameters:
    - image_folder: folder containing the PNG images
    - gif_name: name of the output GIF file
    - duration: duration of each frame in seconds
    - loop: number of times to loop the GIF. 0 means loop indefinitely.
    """
    images = []
    for filename in sorted(os.listdir(image_folder), key=lambda x: int(x.split('_')[1].split('yr')[0])):
        if filename.endswith(".png"):
            file_path = os.path.join(image_folder, filename)
            images.append(imageio.imread(file_path))
    
    imageio.mimsave(gif_name, images, duration=duration, loop=loop)
    print(f"Looping GIF created: {gif_name}")

# For displaying the GIF animation
def display_gif(gif_name):
    display(Image(filename=gif_name))

# %% [markdown]
# ### Model Setup and Initialization
#
# Now, let's set up our model grid and initialize the components. We'll create functions to handle these tasks:

# %%
def setup_model_grid(num_rows=30, num_columns=30, node_spacing=25.0):
    """
    Set up the initial model grid.
    
    Parameters:
    - num_rows: Number of rows in the grid
    - num_columns: Number of columns in the grid
    - node_spacing: Spacing between nodes
    
    Returns:
    - mg: Initialized Landlab RasterModelGrid
    """
    # Create the grid
    mg = RasterModelGrid((num_rows, num_columns), node_spacing)
    
    # Add fields to the grid
    mg.add_zeros("topographic__elevation", at="node")
    mg.add_zeros("soil__depth", at="node")
    mg.add_zeros("bedrock__elevation", at="node")

    # Add random noise to topography for initial roughness
    random_noise = (np.random.rand(len(mg.node_y)) / 1000.0)
    mg["node"]["topographic__elevation"] += random_noise
    
    # Set initial soil depth (1m) at core nodes
    mg.at_node["soil__depth"][mg.core_nodes] = 1.0
    
    # Calculate bedrock elevation as the difference between topographic elevation and soil depth
    mg.at_node["bedrock__elevation"][:] = mg.at_node["topographic__elevation"]
    mg.at_node["topographic__elevation"][:] += mg.at_node["soil__depth"]

    # Set boundary conditions: closed on all sides except one outlet
    mg.set_closed_boundaries_at_grid_edges(True, True, True, True)
    mg.status_at_node[0] = 1  # Set outlet at node 0

    return mg

# %%
def initialize_components(mg):
    """
    Initialize model components.
    
    Parameters:
    - mg: Landlab RasterModelGrid
    
    Returns:
    - fr: Initialized FlowRouter
    - sp: Initialized SpaceLargeScaleEroder
    """
    # Initialize flow router with D8 flow direction method
    fr = PriorityFloodFlowRouter(mg, flow_metric="D8", suppress_out=True)
    
    # Initialize SPACE component for sediment transport and bedrock erosion
    sp = SpaceLargeScaleEroder(
        mg,
        K_sed=2.5e-5,  # Erodibility coefficient for sediment
        K_br=2.5e-5,   # Erodibility coefficient for bedrock
        F_f=0.0,       # Fraction of fine sediment
        phi=0.0,       # Sediment porosity
        H_star=1.0,    # Sediment thickness required for full entrainment
        v_s=1,         # Settling velocity
        m_sp=0.5,      # Drainage area exponent
        n_sp=1.0,      # Slope exponent
        sp_crit_sed=0, # Critical shear stress for sediment
        sp_crit_br=0,  # Critical shear stress for bedrock
    )
    return fr, sp

# %% [markdown]
# ### Simulation Functions
#
# Now let's define our main simulation functions for different scenarios:

# %%
def run_initial_landscape(mg, fr, sp, run_time=1000000, timestep=500, U=0.001):
    """
    Run simulation to generate the initial semi-steady-state landscape.
    
    Parameters:
    - mg: Landlab RasterModelGrid
    - fr: FlowRouter component
    - sp: SpaceLargeScaleEroder component
    - run_time: Total simulation time
    - timestep: Time step for each iteration
    - U: Uplift rate (m/year)
    """
    elapsed_time = 0.0
    while elapsed_time < run_time:
        # Apply uplift to bedrock and update topography
        mg.at_node["bedrock__elevation"][mg.core_nodes] += U * timestep
        mg.at_node["topographic__elevation"][:] = (
            mg.at_node["bedrock__elevation"] + mg.at_node["soil__depth"]
        )
        
        # Route flow and perform erosion/deposition
        fr.run_one_step()
        sp.run_one_step(dt=timestep)
        
        elapsed_time += timestep
        # Print progress every 100,000 years
        if np.mod(elapsed_time, 1e5) == 0:
            print(f"{100 * elapsed_time / run_time:.0f}% of model run completed")

# %%
def run_good_connectivity_scenario(mg, timesteps=20, timestep=1, landsliding=True, U=0.001):
    """
    Run the good connectivity scenario with simultaneous landslides and river incision.
    
    Parameters:
    - mg: Landlab RasterModelGrid
    - timesteps: Number of time steps to run
    - timestep: Duration of each time step
    - landsliding: Boolean to enable/disable landsliding
    - U: Uplift rate (m/year)
    """
    # Initialize flow router with both channel and hillslope flow
    fr = PriorityFloodFlowRouter(
        mg,
        flow_metric="D8",
        separate_hill_flow=True,
        hill_flow_metric="Quinn",
        update_hill_flow_instantaneous=True,
    )
    
    # Initialize landslide component
    hy = BedrockLandslider(
        mg,
        angle_int_frict=0.5,  # Internal friction angle
        cohesion_eff=1e5,     # Effective cohesion
        landslides_return_time=10000,  # Return time for stochastic landslide events to occur (higher means lower slide propablity)
        landslides_on_boundary_nodes=False,
    )
    
    # Initialize gravel-bed river erosion component
    eroder = GravelBedrockEroder(
        mg, 
        abrasion_coefficient=0.0005,  # Rate of downstream fining
        coarse_fraction_from_plucking=0.2  # Fraction of plucked material that becomes coarse sediment
    )

    for _ in range(timesteps):
        # Apply uplift and update topography
        mg.at_node["bedrock__elevation"][mg.core_nodes] += U * timestep
        mg.at_node["topographic__elevation"][:] = (
            mg.at_node["bedrock__elevation"] + mg.at_node["soil__depth"]
        )
        
        # Route flow and perform erosion
        fr.run_one_step()
        eroder.calc_sediment_rate_of_change()
        eroder.run_one_step(timestep)
        
        # Trigger landslides if enabled
        if landsliding:
            hy.run_one_step(dt=timestep)

# %%
def run_bad_connectivity_scenario(mg, landslide_steps=20, river_steps=20, timestep=1, U=0.001):
    """
    Run the bad connectivity scenario with landslides followed by river incision.
    
    Parameters:
    - mg: Landlab RasterModelGrid
    - landslide_steps: Number of time steps for landslide phase
    - river_steps: Number of time steps for river incision phase
    - timestep: Duration of each time step
    - U: Uplift rate (m/year)
    """
    # Initialize components (same as in good connectivity scenario)
    fr = PriorityFloodFlowRouter(
        mg,
        flow_metric="D8",
        separate_hill_flow=True,
        hill_flow_metric="Quinn",
        update_hill_flow_instantaneous=True,
    )
    hy = BedrockLandslider(
        mg,
        angle_int_frict=0.5,
        cohesion_eff=1e5,
        landslides_return_time=10000,  # Return time for stochastic landslide events to occur (higher means lower slide propablity)
        landslides_on_boundary_nodes=False,
    )
    eroder = GravelBedrockEroder(
        mg, abrasion_coefficient=0.0005,
        coarse_fraction_from_plucking=0.2
    )

    # Landslide phase: only uplift and landslides, no river erosion
    for _ in range(landslide_steps):
        mg.at_node["bedrock__elevation"][mg.core_nodes] += U * timestep
        mg.at_node["topographic__elevation"][:] = (
            mg.at_node["bedrock__elevation"] + mg.at_node["soil__depth"]
        )
        hy.run_one_step(dt=timestep)

    # River incision phase: uplift, flow routing, and river erosion
    for _ in range(river_steps):
        mg.at_node["bedrock__elevation"][mg.core_nodes] += U * timestep
        mg.at_node["topographic__elevation"][:] = (
            mg.at_node["bedrock__elevation"] + mg.at_node["soil__depth"]
        )
        fr.run_one_step()
        eroder.calc_sediment_rate_of_change()
        eroder.run_one_step(timestep)

# %% [markdown]
# <hr>
#
# ### Main Execution
#
# Now, let's run our simulations for the different scenarios:
#
# ##### Step 1: Create initial landscape

# %%
print("Generating the Pre-slide Synthetic Landscape via SPACE model")
mg = setup_model_grid()
fr, sp = initialize_components(mg)
run_initial_landscape(mg, fr, sp, run_time=1000000, timestep=500, U=0.001)

# Save initial landscape
with open('pre-slide_fakelandscape.pickle', 'wb') as f:
    pickle.dump(mg, f)

# Plot initial landscape
print("Pre-slide Synthetic Landscape. Background U = 1 mm/yr")
plot_landscape_and_profile(mg, "Pre-slide Synthetic Landscape (U = 1 mm/yr)", showfig=True)
# Out:
# Generating the Pre-slide Synthetic Landscape via SPACE model
# 10% of model run completed
# 20% of model run completed
# 30% of model run completed
# 40% of model run completed
# 50% of model run completed
# 60% of model run completed
# 70% of model run completed
# 80% of model run completed
# 90% of model run completed
# 100% of model run completed
# Pre-slide Synthetic Landscape. Background U = 1 mm/yr

# %%
# Define the duration of catastrophic landslide period
landslide_duration = 20  # years

# %% [markdown]
# ##### Step 2: Good connectivity scenario

# %%
# Create a folder to store images
if not os.path.exists("good_connectivity_frames"):
    os.makedirs("good_connectivity_frames")

# Load the initial landscape and save it as frame_0
print("Synthetic Landscape - GOOD CONNECTIVITY scenario")
mg_good = pickle.load(open('pre-slide_fakelandscape.pickle', 'rb'))
plot_landscape_and_profile(mg_good,
    "GOOD CONNECTIVITY [Year #00000]: Landsliding = OFF; River Bedload Incision = OFF (U = 1 mm/yr)",
    showfig=False,
    savefig=True,
    savefigname="good_connectivity_frames/frame_00000yr.png",
    max_sed_depth=None
    )
print("Saved initial landscape as frame_00000yr.png")

# Run simulation for the first few years when landsliding and river incision are both active
print("Turn ON landsliding and river bedload incision simultaneously. Background U = 1 mm/yr")
maxsd_good = 0
for year in range(5, landslide_duration + 1, 5):
    run_good_connectivity_scenario(mg_good, timesteps=5, timestep=5, landsliding=True, U=0.001)
    maxsd_good = max(maxsd_good, np.nanmax(mg_good.at_node["soil__depth"]))  # Update the maximum soil depth for the y-axis
    plot_landscape_and_profile(mg_good,
        f"GOOD CONNECTIVITY [Year #{year:05d}]: Landsliding = ON ; River Bedload Incision = ON  (U = 1 mm/yr)",
        showfig=False,
        savefig=True,
        savefigname=f"good_connectivity_frames/frame_{year:05d}yr.png",
        max_sed_depth=maxsd_good)
    print(f"Saved landscape at year {year} as frame_{year:05d}yr.png")
print(f"Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr")

# Shut down landslides, and continue to run simulation with only river incision
post_landslide_years = np.concatenate([
    np.arange(landslide_duration + 80, 20000 + 1, 100)
])

for year in post_landslide_years:
    years_to_run = year - (landslide_duration if year == post_landslide_years[0] else post_landslide_years[post_landslide_years.tolist().index(year) - 1])
    run_good_connectivity_scenario(mg_good, timesteps=years_to_run, timestep=1, landsliding=False, U=0.001)
    maxsd_good = max(maxsd_good, np.nanmax(mg_good.at_node["soil__depth"]))  # Update the maximum soil depth for the y-axis
    plot_landscape_and_profile(mg_good,
        f"GOOD CONNECTIVITY [Year #{year:05d}]: Landsliding = OFF; River Bedload Incision = ON  (U = 1 mm/yr)",
        showfig=False,
        savefig=True,
        savefigname=f"good_connectivity_frames/frame_{year:05d}yr.png",
        max_sed_depth=maxsd_good)
    print(f"Saved landscape at year {year} as frame_{year:05d}yr.png")
# Out:
# Synthetic Landscape - GOOD CONNECTIVITY scenario
# Saved initial landscape as frame_00000yr.png
# Turn ON landsliding and river bedload incision simultaneously. Background U = 1 mm/yr
# Saved landscape at year 5 as frame_00005yr.png
# Saved landscape at year 10 as frame_00010yr.png
# Saved landscape at year 15 as frame_00015yr.png
# Saved landscape at year 20 as frame_00020yr.png
# Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr
# Saved landscape at year 100 as frame_00100yr.png
# Saved landscape at year 200 as frame_00200yr.png
# Saved landscape at year 300 as frame_00300yr.png
# Saved landscape at year 400 as frame_00400yr.png
# Saved landscape at year 500 as frame_00500yr.png
# Saved landscape at year 600 as frame_00600yr.png
# Saved landscape at year 700 as frame_00700yr.png
# Saved landscape at year 800 as frame_00800yr.png
# Saved landscape at year 900 as frame_00900yr.png
# Saved landscape at year 1000 as frame_01000yr.png
# Saved landscape at year 1100 as frame_01100yr.png
# Saved landscape at year 1200 as frame_01200yr.png
# Saved landscape at year 1300 as frame_01300yr.png
# Saved landscape at year 1400 as frame_01400yr.png
# Saved landscape at year 1500 as frame_01500yr.png
# Saved landscape at year 1600 as frame_01600yr.png
# Saved landscape at year 1700 as frame_01700yr.png
# Saved landscape at year 1800 as frame_01800yr.png
# Saved landscape at year 1900 as frame_01900yr.png
# Saved landscape at year 2000 as frame_02000yr.png
# Saved landscape at year 2100 as frame_02100yr.png
# Saved landscape at year 2200 as frame_02200yr.png
# Saved landscape at year 2300 as frame_02300yr.png
# Saved landscape at year 2400 as frame_02400yr.png
# Saved landscape at year 2500 as frame_02500yr.png
# Saved landscape at year 2600 as frame_02600yr.png
# Saved landscape at year 2700 as frame_02700yr.png
# Saved landscape at year 2800 as frame_02800yr.png
# Saved landscape at year 2900 as frame_02900yr.png
# Saved landscape at year 3000 as frame_03000yr.png
# Saved landscape at year 3100 as frame_03100yr.png
# Saved landscape at year 3200 as frame_03200yr.png
# Saved landscape at year 3300 as frame_03300yr.png
# Saved landscape at year 3400 as frame_03400yr.png
# Saved landscape at year 3500 as frame_03500yr.png
# Saved landscape at year 3600 as frame_03600yr.png
# Saved landscape at year 3700 as frame_03700yr.png
# Saved landscape at year 3800 as frame_03800yr.png
# Saved landscape at year 3900 as frame_03900yr.png
# Saved landscape at year 4000 as frame_04000yr.png
# Saved landscape at year 4100 as frame_04100yr.png
# Saved landscape at year 4200 as frame_04200yr.png
# Saved landscape at year 4300 as frame_04300yr.png
# Saved landscape at year 4400 as frame_04400yr.png
# Saved landscape at year 4500 as frame_04500yr.png
# Saved landscape at year 4600 as frame_04600yr.png
# Saved landscape at year 4700 as frame_04700yr.png
# Saved landscape at year 4800 as frame_04800yr.png
# Saved landscape at year 4900 as frame_04900yr.png
# Saved landscape at year 5000 as frame_05000yr.png
# Saved landscape at year 5100 as frame_05100yr.png
# Saved landscape at year 5200 as frame_05200yr.png
# Saved landscape at year 5300 as frame_05300yr.png
# Saved landscape at year 5400 as frame_05400yr.png
# Saved landscape at year 5500 as frame_05500yr.png
# Saved landscape at year 5600 as frame_05600yr.png
# Saved landscape at year 5700 as frame_05700yr.png
# Saved landscape at year 5800 as frame_05800yr.png
# Saved landscape at year 5900 as frame_05900yr.png
# Saved landscape at year 6000 as frame_06000yr.png
# Saved landscape at year 6100 as frame_06100yr.png
# Saved landscape at year 6200 as frame_06200yr.png
# Saved landscape at year 6300 as frame_06300yr.png
# Saved landscape at year 6400 as frame_06400yr.png
# Saved landscape at year 6500 as frame_06500yr.png
# Saved landscape at year 6600 as frame_06600yr.png
# Saved landscape at year 6700 as frame_06700yr.png
# Saved landscape at year 6800 as frame_06800yr.png
# Saved landscape at year 6900 as frame_06900yr.png
# Saved landscape at year 7000 as frame_07000yr.png
# Saved landscape at year 7100 as frame_07100yr.png
# Saved landscape at year 7200 as frame_07200yr.png
# Saved landscape at year 7300 as frame_07300yr.png
# Saved landscape at year 7400 as frame_07400yr.png
# Saved landscape at year 7500 as frame_07500yr.png
# Saved landscape at year 7600 as frame_07600yr.png
# Saved landscape at year 7700 as frame_07700yr.png
# Saved landscape at year 7800 as frame_07800yr.png
# Saved landscape at year 7900 as frame_07900yr.png
# Saved landscape at year 8000 as frame_08000yr.png
# Saved landscape at year 8100 as frame_08100yr.png
# Saved landscape at year 8200 as frame_08200yr.png
# Saved landscape at year 8300 as frame_08300yr.png
# Saved landscape at year 8400 as frame_08400yr.png
# Saved landscape at year 8500 as frame_08500yr.png
# Saved landscape at year 8600 as frame_08600yr.png
# Saved landscape at year 8700 as frame_08700yr.png
# Saved landscape at year 8800 as frame_08800yr.png
# Saved landscape at year 8900 as frame_08900yr.png
# Saved landscape at year 9000 as frame_09000yr.png
# Saved landscape at year 9100 as frame_09100yr.png
# Saved landscape at year 9200 as frame_09200yr.png
# Saved landscape at year 9300 as frame_09300yr.png
# Saved landscape at year 9400 as frame_09400yr.png
# Saved landscape at year 9500 as frame_09500yr.png
# Saved landscape at year 9600 as frame_09600yr.png
# Saved landscape at year 9700 as frame_09700yr.png
# Saved landscape at year 9800 as frame_09800yr.png
# Saved landscape at year 9900 as frame_09900yr.png
# Saved landscape at year 10000 as frame_10000yr.png
# Saved landscape at year 10100 as frame_10100yr.png
# Saved landscape at year 10200 as frame_10200yr.png
# Saved landscape at year 10300 as frame_10300yr.png
# Saved landscape at year 10400 as frame_10400yr.png
# Saved landscape at year 10500 as frame_10500yr.png
# Saved landscape at year 10600 as frame_10600yr.png
# Saved landscape at year 10700 as frame_10700yr.png
# Saved landscape at year 10800 as frame_10800yr.png
# Saved landscape at year 10900 as frame_10900yr.png
# Saved landscape at year 11000 as frame_11000yr.png
# Saved landscape at year 11100 as frame_11100yr.png
# Saved landscape at year 11200 as frame_11200yr.png
# Saved landscape at year 11300 as frame_11300yr.png
# Saved landscape at year 11400 as frame_11400yr.png
# Saved landscape at year 11500 as frame_11500yr.png
# Saved landscape at year 11600 as frame_11600yr.png
# Saved landscape at year 11700 as frame_11700yr.png
# Saved landscape at year 11800 as frame_11800yr.png
# Saved landscape at year 11900 as frame_11900yr.png
# Saved landscape at year 12000 as frame_12000yr.png
# Saved landscape at year 12100 as frame_12100yr.png
# Saved landscape at year 12200 as frame_12200yr.png
# Saved landscape at year 12300 as frame_12300yr.png
# Saved landscape at year 12400 as frame_12400yr.png
# Saved landscape at year 12500 as frame_12500yr.png
# Saved landscape at year 12600 as frame_12600yr.png
# Saved landscape at year 12700 as frame_12700yr.png
# Saved landscape at year 12800 as frame_12800yr.png
# Saved landscape at year 12900 as frame_12900yr.png
# Saved landscape at year 13000 as frame_13000yr.png
# Saved landscape at year 13100 as frame_13100yr.png
# Saved landscape at year 13200 as frame_13200yr.png
# Saved landscape at year 13300 as frame_13300yr.png
# Saved landscape at year 13400 as frame_13400yr.png
# Saved landscape at year 13500 as frame_13500yr.png
# Saved landscape at year 13600 as frame_13600yr.png
# Saved landscape at year 13700 as frame_13700yr.png
# Saved landscape at year 13800 as frame_13800yr.png
# Saved landscape at year 13900 as frame_13900yr.png
# Saved landscape at year 14000 as frame_14000yr.png
# Saved landscape at year 14100 as frame_14100yr.png
# Saved landscape at year 14200 as frame_14200yr.png
# Saved landscape at year 14300 as frame_14300yr.png
# Saved landscape at year 14400 as frame_14400yr.png
# Saved landscape at year 14500 as frame_14500yr.png
# Saved landscape at year 14600 as frame_14600yr.png
# Saved landscape at year 14700 as frame_14700yr.png
# Saved landscape at year 14800 as frame_14800yr.png
# Saved landscape at year 14900 as frame_14900yr.png
# Saved landscape at year 15000 as frame_15000yr.png
# Saved landscape at year 15100 as frame_15100yr.png
# Saved landscape at year 15200 as frame_15200yr.png
# Saved landscape at year 15300 as frame_15300yr.png
# Saved landscape at year 15400 as frame_15400yr.png
# Saved landscape at year 15500 as frame_15500yr.png
# Saved landscape at year 15600 as frame_15600yr.png
# Saved landscape at year 15700 as frame_15700yr.png
# Saved landscape at year 15800 as frame_15800yr.png
# Saved landscape at year 15900 as frame_15900yr.png
# Saved landscape at year 16000 as frame_16000yr.png
# Saved landscape at year 16100 as frame_16100yr.png
# Saved landscape at year 16200 as frame_16200yr.png
# Saved landscape at year 16300 as frame_16300yr.png
# Saved landscape at year 16400 as frame_16400yr.png
# Saved landscape at year 16500 as frame_16500yr.png
# Saved landscape at year 16600 as frame_16600yr.png
# Saved landscape at year 16700 as frame_16700yr.png
# Saved landscape at year 16800 as frame_16800yr.png
# Saved landscape at year 16900 as frame_16900yr.png
# Saved landscape at year 17000 as frame_17000yr.png
# Saved landscape at year 17100 as frame_17100yr.png
# Saved landscape at year 17200 as frame_17200yr.png
# Saved landscape at year 17300 as frame_17300yr.png
# Saved landscape at year 17400 as frame_17400yr.png
# Saved landscape at year 17500 as frame_17500yr.png
# Saved landscape at year 17600 as frame_17600yr.png
# Saved landscape at year 17700 as frame_17700yr.png
# Saved landscape at year 17800 as frame_17800yr.png
# Saved landscape at year 17900 as frame_17900yr.png
# Saved landscape at year 18000 as frame_18000yr.png
# Saved landscape at year 18100 as frame_18100yr.png
# Saved landscape at year 18200 as frame_18200yr.png
# Saved landscape at year 18300 as frame_18300yr.png
# Saved landscape at year 18400 as frame_18400yr.png
# Saved landscape at year 18500 as frame_18500yr.png
# Saved landscape at year 18600 as frame_18600yr.png
# Saved landscape at year 18700 as frame_18700yr.png
# Saved landscape at year 18800 as frame_18800yr.png
# Saved landscape at year 18900 as frame_18900yr.png
# Saved landscape at year 19000 as frame_19000yr.png
# Saved landscape at year 19100 as frame_19100yr.png
# Saved landscape at year 19200 as frame_19200yr.png
# Saved landscape at year 19300 as frame_19300yr.png
# Saved landscape at year 19400 as frame_19400yr.png
# Saved landscape at year 19500 as frame_19500yr.png
# Saved landscape at year 19600 as frame_19600yr.png
# Saved landscape at year 19700 as frame_19700yr.png
# Saved landscape at year 19800 as frame_19800yr.png
# Saved landscape at year 19900 as frame_19900yr.png
# Saved landscape at year 20000 as frame_20000yr.png

# %%
# Create the GIF
create_gif("good_connectivity_frames", "good_connectivity_animation.gif", duration=0.35, loop=0)
# loop=0 means the GIF will loop infinitely times.

# Display the created GIF
display_gif("good_connectivity_animation.gif")

# %% [markdown]
# ##### Step 3: Bad connectivity scenario

# %%
# Create a folder to store images
if not os.path.exists("bad_connectivity_frames"):
    os.makedirs("bad_connectivity_frames")

# Load the initial landscape and save it as frame_0
print("Synthetic Landscape - BAD CONNECTIVITY scenario")
mg_bad = pickle.load(open('pre-slide_fakelandscape.pickle', 'rb'))
plot_landscape_and_profile(mg_bad,
    "BAD CONNECTIVITY [Year #00000]: Landsliding = OFF; River Bedload Incision = OFF (U = 1 mm/yr)",
    showfig=False,
    savefig=True,
    savefigname="bad_connectivity_frames/frame_00000yr.png",
    max_sed_depth=None
    )
print("Saved initial landscape as frame_00000yr.png")

# Run landslides without river incision
print("Turn ON landsliding only. Background U = 1 mm/yr")
maxsd_bad = 0
for year in range(5, landslide_duration + 1, 5):
    run_bad_connectivity_scenario(mg_bad, landslide_steps=5, river_steps=0, timestep=5, U=0.001)
    maxsd_bad = max(maxsd_bad, np.nanmax(mg_bad.at_node["soil__depth"]))  # Update the maximum soil depth for the y-axis
    plot_landscape_and_profile(mg_bad,
        f"BAD CONNECTIVITY [Year #{year:05d}]: Landsliding = ON ; River Bedload Incision = OFF (U = 1 mm/yr)",
        showfig=False,
        savefig=True,
        savefigname=f"bad_connectivity_frames/frame_{year:05d}yr.png",
        max_sed_depth=maxsd_bad)
    print(f"Saved landscape at year {year} as frame_{year:05d}yr.png")
print(f"Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr")

# Shut down landslides, and continue to run simulation with only river incision
post_landslide_years = np.concatenate([
    np.arange(landslide_duration + 80, 20000 + 1, 100)
])

for year in post_landslide_years:
    years_to_run = year - (landslide_duration if year == post_landslide_years[0] else post_landslide_years[post_landslide_years.tolist().index(year) - 1])
    run_bad_connectivity_scenario(mg_bad, landslide_steps=0, river_steps=years_to_run, timestep=1, U=0.001)
    maxsd_bad = max(maxsd_bad, np.nanmax(mg_bad.at_node["soil__depth"]))  # Update the maximum soil depth for the y-axis
    plot_landscape_and_profile(mg_bad,
        f"BAD CONNECTIVITY [Year #{year:05d}]: Landsliding = OFF; River Bedload Incision = ON  (U = 1 mm/yr)",
        showfig=False,
        savefig=True,
        savefigname=f"bad_connectivity_frames/frame_{year:05d}yr.png",
        max_sed_depth=maxsd_bad)
    print(f"Saved landscape at year {year} as frame_{year:05d}yr.png")
# Out:
# Synthetic Landscape - BAD CONNECTIVITY scenario
# Saved initial landscape as frame_00000yr.png
# Turn ON landsliding only. Background U = 1 mm/yr
# Saved landscape at year 5 as frame_00005yr.png
# Saved landscape at year 10 as frame_00010yr.png
# Saved landscape at year 15 as frame_00015yr.png
# Saved landscape at year 20 as frame_00020yr.png
# Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr
# Saved landscape at year 100 as frame_00100yr.png
# Saved landscape at year 200 as frame_00200yr.png
# Saved landscape at year 300 as frame_00300yr.png
# Saved landscape at year 400 as frame_00400yr.png
# Saved landscape at year 500 as frame_00500yr.png
# Saved landscape at year 600 as frame_00600yr.png
# Saved landscape at year 700 as frame_00700yr.png
# Saved landscape at year 800 as frame_00800yr.png
# Saved landscape at year 900 as frame_00900yr.png
# Saved landscape at year 1000 as frame_01000yr.png
# Saved landscape at year 1100 as frame_01100yr.png
# Saved landscape at year 1200 as frame_01200yr.png
# Saved landscape at year 1300 as frame_01300yr.png
# Saved landscape at year 1400 as frame_01400yr.png
# Saved landscape at year 1500 as frame_01500yr.png
# Saved landscape at year 1600 as frame_01600yr.png
# Saved landscape at year 1700 as frame_01700yr.png
# Saved landscape at year 1800 as frame_01800yr.png
# Saved landscape at year 1900 as frame_01900yr.png
# Saved landscape at year 2000 as frame_02000yr.png
# Saved landscape at year 2100 as frame_02100yr.png
# Saved landscape at year 2200 as frame_02200yr.png
# Saved landscape at year 2300 as frame_02300yr.png
# Saved landscape at year 2400 as frame_02400yr.png
# Saved landscape at year 2500 as frame_02500yr.png
# Saved landscape at year 2600 as frame_02600yr.png
# Saved landscape at year 2700 as frame_02700yr.png
# Saved landscape at year 2800 as frame_02800yr.png
# Saved landscape at year 2900 as frame_02900yr.png
# Saved landscape at year 3000 as frame_03000yr.png
# Saved landscape at year 3100 as frame_03100yr.png
# Saved landscape at year 3200 as frame_03200yr.png
# Saved landscape at year 3300 as frame_03300yr.png
# Saved landscape at year 3400 as frame_03400yr.png
# Saved landscape at year 3500 as frame_03500yr.png
# Saved landscape at year 3600 as frame_03600yr.png
# Saved landscape at year 3700 as frame_03700yr.png
# Saved landscape at year 3800 as frame_03800yr.png
# Saved landscape at year 3900 as frame_03900yr.png
# Saved landscape at year 4000 as frame_04000yr.png
# Saved landscape at year 4100 as frame_04100yr.png
# Saved landscape at year 4200 as frame_04200yr.png
# Saved landscape at year 4300 as frame_04300yr.png
# Saved landscape at year 4400 as frame_04400yr.png
# Saved landscape at year 4500 as frame_04500yr.png
# Saved landscape at year 4600 as frame_04600yr.png
# Saved landscape at year 4700 as frame_04700yr.png
# Saved landscape at year 4800 as frame_04800yr.png
# Saved landscape at year 4900 as frame_04900yr.png
# Saved landscape at year 5000 as frame_05000yr.png
# Saved landscape at year 5100 as frame_05100yr.png
# Saved landscape at year 5200 as frame_05200yr.png
# Saved landscape at year 5300 as frame_05300yr.png
# Saved landscape at year 5400 as frame_05400yr.png
# Saved landscape at year 5500 as frame_05500yr.png
# Saved landscape at year 5600 as frame_05600yr.png
# Saved landscape at year 5700 as frame_05700yr.png
# Saved landscape at year 5800 as frame_05800yr.png
# Saved landscape at year 5900 as frame_05900yr.png
# Saved landscape at year 6000 as frame_06000yr.png
# Saved landscape at year 6100 as frame_06100yr.png
# Saved landscape at year 6200 as frame_06200yr.png
# Saved landscape at year 6300 as frame_06300yr.png
# Saved landscape at year 6400 as frame_06400yr.png
# Saved landscape at year 6500 as frame_06500yr.png
# Saved landscape at year 6600 as frame_06600yr.png
# Saved landscape at year 6700 as frame_06700yr.png
# Saved landscape at year 6800 as frame_06800yr.png
# Saved landscape at year 6900 as frame_06900yr.png
# Saved landscape at year 7000 as frame_07000yr.png
# Saved landscape at year 7100 as frame_07100yr.png
# Saved landscape at year 7200 as frame_07200yr.png
# Saved landscape at year 7300 as frame_07300yr.png
# Saved landscape at year 7400 as frame_07400yr.png
# Saved landscape at year 7500 as frame_07500yr.png
# Saved landscape at year 7600 as frame_07600yr.png
# Saved landscape at year 7700 as frame_07700yr.png
# Saved landscape at year 7800 as frame_07800yr.png
# Saved landscape at year 7900 as frame_07900yr.png
# Saved landscape at year 8000 as frame_08000yr.png
# Saved landscape at year 8100 as frame_08100yr.png
# Saved landscape at year 8200 as frame_08200yr.png
# Saved landscape at year 8300 as frame_08300yr.png
# Saved landscape at year 8400 as frame_08400yr.png
# Saved landscape at year 8500 as frame_08500yr.png
# Saved landscape at year 8600 as frame_08600yr.png
# Saved landscape at year 8700 as frame_08700yr.png
# Saved landscape at year 8800 as frame_08800yr.png
# Saved landscape at year 8900 as frame_08900yr.png
# Saved landscape at year 9000 as frame_09000yr.png
# Saved landscape at year 9100 as frame_09100yr.png
# Saved landscape at year 9200 as frame_09200yr.png
# Saved landscape at year 9300 as frame_09300yr.png
# Saved landscape at year 9400 as frame_09400yr.png
# Saved landscape at year 9500 as frame_09500yr.png
# Saved landscape at year 9600 as frame_09600yr.png
# Saved landscape at year 9700 as frame_09700yr.png
# Saved landscape at year 9800 as frame_09800yr.png
# Saved landscape at year 9900 as frame_09900yr.png
# Saved landscape at year 10000 as frame_10000yr.png
# Saved landscape at year 10100 as frame_10100yr.png
# Saved landscape at year 10200 as frame_10200yr.png
# Saved landscape at year 10300 as frame_10300yr.png
# Saved landscape at year 10400 as frame_10400yr.png
# Saved landscape at year 10500 as frame_10500yr.png
# Saved landscape at year 10600 as frame_10600yr.png
# Saved landscape at year 10700 as frame_10700yr.png
# Saved landscape at year 10800 as frame_10800yr.png
# Saved landscape at year 10900 as frame_10900yr.png
# Saved landscape at year 11000 as frame_11000yr.png
# Saved landscape at year 11100 as frame_11100yr.png
# Saved landscape at year 11200 as frame_11200yr.png
# Saved landscape at year 11300 as frame_11300yr.png
# Saved landscape at year 11400 as frame_11400yr.png
# Saved landscape at year 11500 as frame_11500yr.png
# Saved landscape at year 11600 as frame_11600yr.png
# Saved landscape at year 11700 as frame_11700yr.png
# Saved landscape at year 11800 as frame_11800yr.png
# Saved landscape at year 11900 as frame_11900yr.png
# Saved landscape at year 12000 as frame_12000yr.png
# Saved landscape at year 12100 as frame_12100yr.png
# Saved landscape at year 12200 as frame_12200yr.png
# Saved landscape at year 12300 as frame_12300yr.png
# Saved landscape at year 12400 as frame_12400yr.png
# Saved landscape at year 12500 as frame_12500yr.png
# Saved landscape at year 12600 as frame_12600yr.png
# Saved landscape at year 12700 as frame_12700yr.png
# Saved landscape at year 12800 as frame_12800yr.png
# Saved landscape at year 12900 as frame_12900yr.png
# Saved landscape at year 13000 as frame_13000yr.png
# Saved landscape at year 13100 as frame_13100yr.png
# Saved landscape at year 13200 as frame_13200yr.png
# Saved landscape at year 13300 as frame_13300yr.png
# Saved landscape at year 13400 as frame_13400yr.png
# Saved landscape at year 13500 as frame_13500yr.png
# Saved landscape at year 13600 as frame_13600yr.png
# Saved landscape at year 13700 as frame_13700yr.png
# Saved landscape at year 13800 as frame_13800yr.png
# Saved landscape at year 13900 as frame_13900yr.png
# Saved landscape at year 14000 as frame_14000yr.png
# Saved landscape at year 14100 as frame_14100yr.png
# Saved landscape at year 14200 as frame_14200yr.png
# Saved landscape at year 14300 as frame_14300yr.png
# Saved landscape at year 14400 as frame_14400yr.png
# Saved landscape at year 14500 as frame_14500yr.png
# Saved landscape at year 14600 as frame_14600yr.png
# Saved landscape at year 14700 as frame_14700yr.png
# Saved landscape at year 14800 as frame_14800yr.png
# Saved landscape at year 14900 as frame_14900yr.png
# Saved landscape at year 15000 as frame_15000yr.png
# Saved landscape at year 15100 as frame_15100yr.png
# Saved landscape at year 15200 as frame_15200yr.png
# Saved landscape at year 15300 as frame_15300yr.png
# Saved landscape at year 15400 as frame_15400yr.png
# Saved landscape at year 15500 as frame_15500yr.png
# Saved landscape at year 15600 as frame_15600yr.png
# Saved landscape at year 15700 as frame_15700yr.png
# Saved landscape at year 15800 as frame_15800yr.png
# Saved landscape at year 15900 as frame_15900yr.png
# Saved landscape at year 16000 as frame_16000yr.png
# Saved landscape at year 16100 as frame_16100yr.png
# Saved landscape at year 16200 as frame_16200yr.png
# Saved landscape at year 16300 as frame_16300yr.png
# Saved landscape at year 16400 as frame_16400yr.png
# Saved landscape at year 16500 as frame_16500yr.png
# Saved landscape at year 16600 as frame_16600yr.png
# Saved landscape at year 16700 as frame_16700yr.png
# Saved landscape at year 16800 as frame_16800yr.png
# Saved landscape at year 16900 as frame_16900yr.png
# Saved landscape at year 17000 as frame_17000yr.png
# Saved landscape at year 17100 as frame_17100yr.png
# Saved landscape at year 17200 as frame_17200yr.png
# Saved landscape at year 17300 as frame_17300yr.png
# Saved landscape at year 17400 as frame_17400yr.png
# Saved landscape at year 17500 as frame_17500yr.png
# Saved landscape at year 17600 as frame_17600yr.png
# Saved landscape at year 17700 as frame_17700yr.png
# Saved landscape at year 17800 as frame_17800yr.png
# Saved landscape at year 17900 as frame_17900yr.png
# Saved landscape at year 18000 as frame_18000yr.png
# Saved landscape at year 18100 as frame_18100yr.png
# Saved landscape at year 18200 as frame_18200yr.png
# Saved landscape at year 18300 as frame_18300yr.png
# Saved landscape at year 18400 as frame_18400yr.png
# Saved landscape at year 18500 as frame_18500yr.png
# Saved landscape at year 18600 as frame_18600yr.png
# Saved landscape at year 18700 as frame_18700yr.png
# Saved landscape at year 18800 as frame_18800yr.png
# Saved landscape at year 18900 as frame_18900yr.png
# Saved landscape at year 19000 as frame_19000yr.png
# Saved landscape at year 19100 as frame_19100yr.png
# Saved landscape at year 19200 as frame_19200yr.png
# Saved landscape at year 19300 as frame_19300yr.png
# Saved landscape at year 19400 as frame_19400yr.png
# Saved landscape at year 19500 as frame_19500yr.png
# Saved landscape at year 19600 as frame_19600yr.png
# Saved landscape at year 19700 as frame_19700yr.png
# Saved landscape at year 19800 as frame_19800yr.png
# Saved landscape at year 19900 as frame_19900yr.png
# Saved landscape at year 20000 as frame_20000yr.png

# %%
# Create the GIF
create_gif("bad_connectivity_frames", "bad_connectivity_animation.gif", duration=0.35, loop=0)
# loop=0 means the GIF will loop infinitely times.

# Display the created GIF
display_gif("bad_connectivity_animation.gif")

# %% [markdown]
# ***Notes:***
#
# You may think >30-50 meters of landslide deposit is unrealistic, but here is a great example showing > ~80 m deposit generated by a single landslide event at southwestern Taiwan in 2009:
#
# <img src="shiaolinTWslide.jpg" alt="drawing" width="600"/>
#
# *2009 Shaolin Landlside, Taiwan (image from AGU: https://blogs.agu.org/landslideblog/2010/02/02/the-causes-of-the-shiaolin-landslide-disaster-in-taiwan/)*

# %% [markdown]
# <hr>
#
# ### STEP EXTRA: Analysis with Real Landscape DEM
#
# Now, we'll analyze a real landscape DEM to test the bad connectivity scenario. This step involves loading a pre-existing DEM, imposing landslide events, and then simulating river incision over various time periods.

# %% [markdown]
# ##### Load pre-landslide real landscape

# %%
with open('pre-slide_reallandscape.pickle', 'rb') as g:
    mg2 = pickle.load(g)

print("Pre-Slide Real Landscape")
plot_landscape_and_profile(mg2, "BAD CONNECTIVITY [Year #00000]: Landsliding = OFF; River Bedload Incision = ON")
# Out:
# Pre-Slide Real Landscape

# %% [markdown]
# ##### Load post-landslide landscape (using BedrockLandslider)

# %%
with open('post-slide_reallandscape_BRL.pickle', 'rb') as g:
    mg3 = pickle.load(g)

print("Post-Slide - BAD CONNECTIVITY, before river sediment transport and incision")
plot_landscape_and_profile(mg3, "BAD CONNECTIVITY [Year #00000]: Landsliding = ON; River Bedload Incision = OFF")
# Out:
# Post-Slide - BAD CONNECTIVITY, before river sediment transport and incision

# %% [markdown]
# ##### Run GravelBedrockEroder for different time periods

# %%
# Create a folder to store images
if not os.path.exists("real_landscape_frames"):
    os.makedirs("real_landscape_frames")

# Load the pre-landslide real landscape
print("Real Landscape - BAD CONNECTIVITY scenario")
with open('pre-slide_reallandscape.pickle', 'rb') as g:
    mg_real = pickle.load(g)

plot_landscape_and_profile(mg_real,
    "BAD CONNECTIVITY [Year #00000]: Landsliding = OFF; River Bedload Incision = OFF (U = ? mm/yr)",
    showfig=False,
    savefig=True,
    savefigname="real_landscape_frames/frame_00000yr.png",
    max_sed_depth=None
)
print("Saved initial landscape as frame_00000yr.png")

# Run landslides without river incision
print("Turn ON landsliding only for 20 years. Background U = 1 mm/yr")
with open('post-slide_reallandscape_BRL.pickle', 'rb') as g:
    mg_real = pickle.load(g)

plot_landscape_and_profile(mg_real,
    "BAD CONNECTIVITY [Year #00020]: Landsliding = ON ; River Bedload Incision = OFF (U = ? mm/yr)",
    showfig=False,
    savefig=True,
    savefigname="real_landscape_frames/frame_00020yr.png",
    max_sed_depth=None
)
print("Saved initial landscape as frame_00020yr.png")
print(f"Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr")

# Shut down landslides, and continue to run simulation with only river incision
post_landslide_years = np.concatenate([
    np.arange(landslide_duration + 80, 10000 + 1, 100)
])

for year in post_landslide_years:
    years_to_run = year - (landslide_duration if year == post_landslide_years[0] else post_landslide_years[post_landslide_years.tolist().index(year) - 1])
    run_bad_connectivity_scenario(mg_real, landslide_steps=0, river_steps=years_to_run, timestep=1, U=0.001)
    plot_landscape_and_profile(mg_real,
        f"REAL LANDSCAPE [Year #{year:05d}]: Landsliding = OFF; River Bedload Incision = ON (U = 1 mm/yr)",
        showfig=False,
        savefig=True,
        savefigname=f"real_landscape_frames/frame_{year:05d}yr.png",
        max_sed_depth=10)
    print(f"Saved landscape at year {year} as frame_{year:05d}yr.png")
# Out:
# Real Landscape - BAD CONNECTIVITY scenario
# Saved initial landscape as frame_00000yr.png
# Turn ON landsliding only for 20 years. Background U = 1 mm/yr
# Saved initial landscape as frame_00020yr.png
# Turn OFF landsliding. Continue river bedload incision. Background U = 1 mm/yr
# Saved landscape at year 100 as frame_00100yr.png
# Saved landscape at year 200 as frame_00200yr.png
# Saved landscape at year 300 as frame_00300yr.png
# Saved landscape at year 400 as frame_00400yr.png
# Saved landscape at year 500 as frame_00500yr.png
# Saved landscape at year 600 as frame_00600yr.png
# Saved landscape at year 700 as frame_00700yr.png
# Saved landscape at year 800 as frame_00800yr.png
# Saved landscape at year 900 as frame_00900yr.png
# Saved landscape at year 1000 as frame_01000yr.png
# Saved landscape at year 1100 as frame_01100yr.png
# Saved landscape at year 1200 as frame_01200yr.png
# Saved landscape at year 1300 as frame_01300yr.png
# Saved landscape at year 1400 as frame_01400yr.png
# Saved landscape at year 1500 as frame_01500yr.png
# Saved landscape at year 1600 as frame_01600yr.png
# Saved landscape at year 1700 as frame_01700yr.png
# Saved landscape at year 1800 as frame_01800yr.png
# Saved landscape at year 1900 as frame_01900yr.png
# Saved landscape at year 2000 as frame_02000yr.png
# Saved landscape at year 2100 as frame_02100yr.png
# Saved landscape at year 2200 as frame_02200yr.png
# Saved landscape at year 2300 as frame_02300yr.png
# Saved landscape at year 2400 as frame_02400yr.png
# Saved landscape at year 2500 as frame_02500yr.png
# Saved landscape at year 2600 as frame_02600yr.png
# Saved landscape at year 2700 as frame_02700yr.png
# Saved landscape at year 2800 as frame_02800yr.png
# Saved landscape at year 2900 as frame_02900yr.png
# Saved landscape at year 3000 as frame_03000yr.png
# Saved landscape at year 3100 as frame_03100yr.png
# Saved landscape at year 3200 as frame_03200yr.png
# Saved landscape at year 3300 as frame_03300yr.png
# Saved landscape at year 3400 as frame_03400yr.png
# Saved landscape at year 3500 as frame_03500yr.png
# Saved landscape at year 3600 as frame_03600yr.png
# Saved landscape at year 3700 as frame_03700yr.png
# Saved landscape at year 3800 as frame_03800yr.png
# Saved landscape at year 3900 as frame_03900yr.png
# Saved landscape at year 4000 as frame_04000yr.png
# Saved landscape at year 4100 as frame_04100yr.png
# Saved landscape at year 4200 as frame_04200yr.png
# Saved landscape at year 4300 as frame_04300yr.png
# Saved landscape at year 4400 as frame_04400yr.png
# Saved landscape at year 4500 as frame_04500yr.png
# Saved landscape at year 4600 as frame_04600yr.png
# Saved landscape at year 4700 as frame_04700yr.png
# Saved landscape at year 4800 as frame_04800yr.png
# Saved landscape at year 4900 as frame_04900yr.png
# Saved landscape at year 5000 as frame_05000yr.png
# Saved landscape at year 5100 as frame_05100yr.png
# Saved landscape at year 5200 as frame_05200yr.png
# Saved landscape at year 5300 as frame_05300yr.png
# Saved landscape at year 5400 as frame_05400yr.png
# Saved landscape at year 5500 as frame_05500yr.png
# Saved landscape at year 5600 as frame_05600yr.png
# Saved landscape at year 5700 as frame_05700yr.png
# Saved landscape at year 5800 as frame_05800yr.png
# Saved landscape at year 5900 as frame_05900yr.png
# Saved landscape at year 6000 as frame_06000yr.png
# Saved landscape at year 6100 as frame_06100yr.png
# Saved landscape at year 6200 as frame_06200yr.png
# Saved landscape at year 6300 as frame_06300yr.png
# Saved landscape at year 6400 as frame_06400yr.png
# Saved landscape at year 6500 as frame_06500yr.png
# Saved landscape at year 6600 as frame_06600yr.png
# Saved landscape at year 6700 as frame_06700yr.png
# Saved landscape at year 6800 as frame_06800yr.png
# Saved landscape at year 6900 as frame_06900yr.png
# Saved landscape at year 7000 as frame_07000yr.png
# Saved landscape at year 7100 as frame_07100yr.png
# Saved landscape at year 7200 as frame_07200yr.png
# Saved landscape at year 7300 as frame_07300yr.png
# Saved landscape at year 7400 as frame_07400yr.png
# Saved landscape at year 7500 as frame_07500yr.png
# Saved landscape at year 7600 as frame_07600yr.png
# Saved landscape at year 7700 as frame_07700yr.png
# Saved landscape at year 7800 as frame_07800yr.png
# Saved landscape at year 7900 as frame_07900yr.png
# Saved landscape at year 8000 as frame_08000yr.png
# Saved landscape at year 8100 as frame_08100yr.png
# Saved landscape at year 8200 as frame_08200yr.png
# Saved landscape at year 8300 as frame_08300yr.png
# Saved landscape at year 8400 as frame_08400yr.png
# Saved landscape at year 8500 as frame_08500yr.png
# Saved landscape at year 8600 as frame_08600yr.png
# Saved landscape at year 8700 as frame_08700yr.png
# Saved landscape at year 8800 as frame_08800yr.png
# Saved landscape at year 8900 as frame_08900yr.png
# Saved landscape at year 9000 as frame_09000yr.png
# Saved landscape at year 9100 as frame_09100yr.png
# Saved landscape at year 9200 as frame_09200yr.png
# Saved landscape at year 9300 as frame_09300yr.png
# Saved landscape at year 9400 as frame_09400yr.png
# Saved landscape at year 9500 as frame_09500yr.png
# Saved landscape at year 9600 as frame_09600yr.png
# Saved landscape at year 9700 as frame_09700yr.png
# Saved landscape at year 9800 as frame_09800yr.png
# Saved landscape at year 9900 as frame_09900yr.png
# Saved landscape at year 10000 as frame_10000yr.png

# %%
# Create the GIF
create_gif("real_landscape_frames", "real_landscape_animation.gif", duration=0.35, loop=0)
# loop=0 means the GIF will loop infinitely times.

# Display the created GIF
display_gif("real_landscape_animation.gif")

# %% [markdown]
# <hr>
#
# ### Summary of Main Findings
#
# 1. This notebook allows users to explore landslide-fluvial interaction using both synthetic and real landscapes.
#
# 2. Running simulations with a small synthetic landscape (watershed), we found:
#
#     * Landslide-derived sediments can be evacuated more quickly in high hillslope-channel connectivity scenarios.
#     * The evacuation of landslide-derived sediments in the low-connectivity scenario is on the order of 10^3 years.
#     * The sediment pulse in the high-connectivity scenario appears to translate, whereas in the low-connectivity scenario the pulse appears to diffuse across the long profile.
#
# 3. Running simulations with a large real landscape, we found:
#
#     * Our simulation results reveal how landslides and landslide-derived river sediment pulses modulate a knickpoint in time and space.
#
# These findings highlight the importance of considering landscape connectivity when studying the long-term effects of landslides on river systems and overall landscape evolution.
